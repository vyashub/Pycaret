# %% [markdown]
# # Model Analysis

# %%
pip install pycaret

# %% [markdown]
# # Plot Model

# %%
# Importing dataset
from pycaret.datasets import get_data
diabetes = get_data('diabetes')

# Importing module and initializing setup
from pycaret.classification import *
clf1 = setup(data = diabetes, target = 'Class variable',silent=True)

# creating a model
lr = create_model('lr')

# %% [markdown]
# https://pycaret.org/plot-model/
#
# https://towardsdatascience.com/understanding-confusion-matrix-a9ad42dcfd62

# %%
# Total test rows: 231
# Correct Predictions: 167
# In-Correct Prediction: 64
# plotting a model
plot_model(lr,'confusion_matrix')

# %% [markdown]
# ## Interpret Model
# https://pycaret.org/interpret-model/
#
# SHAP based on Game Theory by Scott Lundberg

# %% [markdown]
# # Summary Plot

# %%
# Importing dataset
from pycaret.datasets import get_data
diabetes = get_data('diabetes')

# Importing module and initializing setup
from pycaret.classification import *
clf1 = setup(data = diabetes, target = 'Class variable',silent=True)

# creating a model
xgboost = create_model('xgboost')

# interpreting model
interpret_model(xgboost)
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa
# 0       0.7778  0.7639  0.6316  0.7059  0.6667  0.5008
# 1       0.7593  0.8015  0.5263  0.7143  0.6061  0.4384
# 2       0.6667  0.7489  0.4737  0.5294  0.5000  0.2512
# 3       0.6667  0.7594  0.5263  0.5263  0.5263  0.2692
# 4       0.7778  0.8602  0.6316  0.7059  0.6667  0.5008
# 5       0.8704  0.9203  0.6842  0.9286  0.7879  0.6976
# 6       0.8704  0.9429  0.8947  0.7727  0.8293  0.7257
# 7       0.7547  0.8508  0.5000  0.6923  0.5806  0.4136
# 8       0.8679  0.8317  0.7222  0.8667  0.7879  0.6931
# 9       0.7358  0.8540  0.7222  0.5909  0.6500  0.4413
# Mean    0.7747  0.8334  0.6313  0.7033  0.6601  0.4932
# SD      0.0725  0.0628  0.1236  0.1252  0.1069  0.1602

# %% [markdown]
# ## Reason Plot at Observation Level

# %%
interpret_model(xgboost, plot = 'reason', observation = 4)
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=189)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";funct
# ...

# %%
interpret_model(xgboost, plot = 'reason', observation = 13)
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=189)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";funct
# ...

# %% [markdown]
# # Assign Model
#
# https://pycaret.org/assign-model/

# %%
#import the dataset from pycaret repository
from pycaret.datasets import get_data
jewellery = get_data('jewellery')
#import clustering module
from pycaret.clustering import *
#intialize the setup
exp_clu = setup(jewellery)
# Out:
# Setup Succesfully Completed!
# <style  type="text/css" >
# </style><table id="T_7dc50186_c772_11ea_9fc0_0242ac1c0002" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_7dc50186_c772_11ea_9fc0_0242ac1c0002level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_7dc50186_c772_11ea_9fc0_0242ac1c0002row0_col0" class="data row0 col0" >session_id </td>
#                         <td id="T_7dc50186_c772_11ea_9fc0_0242ac1c0002row0_col1" class="data row0 col1" >4233</td>
#             </tr>
#             <tr>
#                         <th id="T_7dc50186_c772_11ea_9fc0_0242ac1c0002level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_7dc50186_c772_11ea_9fc0_0242ac1c0002row1_col0" class="data row1 col0" >Original Data </td>
# ...

# %%
jewellery.head()
# Out:
#    Age  Income  SpendingScore       Savings
# 0   58   77769       0.791329   6559.829923
# 1   59   81799       0.791082   5417.661426
# 2   62   74751       0.702657   9258.992965
# 3   59   74373       0.765680   7346.334504
# 4   87   17760       0.348778  16869.507130

# %%
kmeans = create_model('kmeans')

# %%
# calibrate a model
kmeans_result = assign_model(kmeans)
kmeans_result.head()
# Out:
#    Age  Income  SpendingScore       Savings    Cluster
# 0   58   77769       0.791329   6559.829923  Cluster 2
# 1   59   81799       0.791082   5417.661426  Cluster 2
# 2   62   74751       0.702657   9258.992965  Cluster 2
# 3   59   74373       0.765680   7346.334504  Cluster 2
# 4   87   17760       0.348778  16869.507130  Cluster 0

# %% [markdown]
# # Calibrate Model
#
# https://machinelearningmastery.com/calibrated-classification-model-in-scikit-learn/
#
# https://pycaret.org/calibrate-model/

# %%
# Importing dataset
from pycaret.datasets import get_data
diabetes = get_data('diabetes')
# Importing module and initializing setup
from pycaret.classification import *
clf1 = setup(data = diabetes, target = 'Class variable',silent=True)
# create a model
dt = create_model('dt',method='Boosting',ensemble=True)
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa
# 0       0.7037  0.6992  0.6842  0.5652  0.6190  0.3802
# 1       0.7963  0.7707  0.6842  0.7222  0.7027  0.5479
# 2       0.6481  0.5962  0.4211  0.5000  0.4571  0.1997
# 3       0.6667  0.6707  0.6842  0.5200  0.5909  0.3184
# 4       0.7593  0.7421  0.6842  0.6500  0.6667  0.4785
# 5       0.6667  0.6346  0.5263  0.5263  0.5263  0.2692
# 6       0.7407  0.7158  0.6316  0.6316  0.6316  0.4316
# 7       0.7358  0.7056  0.6111  0.6111  0.6111  0.4111
# 8       0.6415  0.6071  0.5000  0.4737  0.4865  0.2114
# 9       0.6792  0.6492  0.5556  0.5263  0.5405  0.2944
# Mean    0.7038  0.6791  0.5982  0.5726  0.5833  0.3542
# SD      0.0494  0.0546  0.0888  0.0745  0.0748  0.1092

# %%
plot_model(dt,plot='calibration')

# %%
# After Calibration
# calibrate a model
calibrated_dt = calibrate_model(dt)
plot_model(calibrated_dt ,plot='calibration')
